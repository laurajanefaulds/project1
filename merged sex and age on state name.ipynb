# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
new_data_path1 = "resources/Provisional_COVID-19_Deaths_by_Sex_and_Age.csv"
new_data_path2 = "resources/US-2-letter-state-code.csv"

# Read the mouse data and the study results
new_data_1_df = pd.read_csv(new_data_path1)
new_data_2_df = pd.read_csv(new_data_path2)

new_data_1_df.head()
# Out:
#    Data As Of  Start Date    End Date     Group  Year  Month          State  \
# 0  05/31/2023  01/01/2020  05/27/2023  By Total   NaN    NaN  United States
# 1  05/31/2023  01/01/2020  05/27/2023  By Total   NaN    NaN  United States
# 2  05/31/2023  01/01/2020  05/27/2023  By Total   NaN    NaN  United States
# 3  05/31/2023  01/01/2020  05/27/2023  By Total   NaN    NaN  United States
# 4  05/31/2023  01/01/2020  05/27/2023  By Total   NaN    NaN  United States
#
#          Sex     Age Group  COVID-19 Deaths  Total Deaths  Pneumonia Deaths  \
# 0  All Sexes      All Ages        1133028.0    11334700.0         1109886.0
# 1  All Sexes  Under 1 year            491.0       66761.0             943.0
# 2  All Sexes    0-17 years           1636.0      118939.0            2655.0
# 3  All Sexes     1-4 years            272.0       12861.0             603.0
# 4  All Sexes    5-14 years            493.0       20007.0             747.0
#
# ...

# %%
new_data_2_df = new_data_2_df.rename(columns={"state_name":"State"})
new_data_2_df
# Out:
#                              State state_code
# 0                          Alabama         AL
# 1                           Alaska         AK
# 2                   American Samoa         AS
# 3                          Arizona         AZ
# 4                         Arkansas         AR
# 5                       California         CA
# 6                         Colorado         CO
# 7                      Connecticut         CT
# 8                         Delaware         DE
# 9             District of Columbia         DC
# 10  Federated States of Micronesia         FM
# 11                         Florida         FL
# 12                         Georgia         GA
# 13                            Guam         GU
# 14                          Hawaii         HI
# 15                           Idaho         ID
# 16                        Illinois         IL
# 17                         Indiana         IN
# 18                            Iowa         IA
# ...

# %%
state_combined_df = pd.merge(new_data_1_df, new_data_2_df,
                                 how='left', on='State')
state_combined_df
# Out:
#         Data As Of  Start Date    End Date     Group    Year  Month  \
# 0       05/31/2023  01/01/2020  05/27/2023  By Total     NaN    NaN
# 1       05/31/2023  01/01/2020  05/27/2023  By Total     NaN    NaN
# 2       05/31/2023  01/01/2020  05/27/2023  By Total     NaN    NaN
# 3       05/31/2023  01/01/2020  05/27/2023  By Total     NaN    NaN
# 4       05/31/2023  01/01/2020  05/27/2023  By Total     NaN    NaN
# ...            ...         ...         ...       ...     ...    ...
# 126679  05/31/2023  05/01/2023  05/27/2023  By Month  2023.0    5.0
# 126680  05/31/2023  05/01/2023  05/27/2023  By Month  2023.0    5.0
# 126681  05/31/2023  05/01/2023  05/27/2023  By Month  2023.0    5.0
# 126682  05/31/2023  05/01/2023  05/27/2023  By Month  2023.0    5.0
# 126683  05/31/2023  05/01/2023  05/27/2023  By Month  2023.0    5.0
#
#                 State        Sex          Age Group  COVID-19 Deaths  \
# 0       United States  All Sexes           All Ages        1133028.0
# ...

# %%
state_combined_df = state_combined_df.dropna(how='any')
state_combined_df
# Out:
# Empty DataFrame
# Columns: [Data As Of, Start Date, End Date, Group, Year, Month, State, Sex, Age Group, COVID-19 Deaths, Total Deaths, Pneumonia Deaths, Pneumonia and COVID-19 Deaths, Influenza Deaths, Pneumonia, Influenza, or COVID-19 Deaths, Footnote, state_code]
# Index: []
